-- %%
CREATE TABLE if not exists unity_cata_workspace.source.customers(
  id INT,
  name VARCHAR(20),
  city VARCHAR(20)
);


insert into unity_cata_workspace.source.customers(id ,name , city)
values 
(1,'John','NY'),
(2,'Mary','LA'),
(3,'Bob','NY'),
(4,'Sara','LA'),
(5,'Mike','NY'),
(6,'Jane','LA'),
(7,'Tom','NY'),
(8,'Lucy','LA'),
(9,'Jack','NY'),
(10,'Lucy','LA')
;

create table if not exists unity_cata_workspace.source.products
(
  p_id int ,
  c_id int ,
  p_name string,
  p_category string,
  p_price double,
  update_time timestamp
);

insert into unity_cata_workspace.source.products
values
(1,1,'p1','electronics',100,'2023-01-01'),
(2,1,'p2','electronics',200,'2023-01-02'),
(3,2,'p3','electronics',300,'2023-01-03'),
(4,3,'p4','electronics',400,'2023-01-04'),
(5,3,'p5','electronics',500,'2023-01-05'),
(6,4,'p6','electronics',600,'2023-01-06'),
(7,5,'p7','electronics',700,'2023-01-07'),
(8,6,'p8','electronics',800,'2023-01-08'),
(9,7,'p9','electronics',900,'2023-01-09'),
(10,8,'p10','electronics',1000,'2023-01-10')
;

insert into unity_cata_workspace.source.products
values(10,8,'p10','electronics',500,'2023-01-11');

alter table unity_cata_workspace.source.products
set tblproperties(DELTA.enableChangeDataFeed = true )
